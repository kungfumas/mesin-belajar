# %% [markdown]
# <a href="https://colab.research.google.com/github/kungfumas/mesin-belajar/blob/master/3_Object_Detection_and_MOT_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Multiple Object Tracking with PyTorch**
#
#
#
# ---
# **Reference**
#
#
# *   Object Detection with Faster R-CNN: https://www.learnopencv.com/faster-r-cnn-object-detection-with-pytorch/
# *   Simple Online and Realtime Tracking (SORT) algorithm for object ID tracking: https://arxiv.org/abs/1602.00763
#
#
# **Question**
# : What is Multiple Object Tracking?
# - Object tracking is one of the tasks in computer vision, which is detecting an object and searching for that object in a video or a series of images (actually both meaning the same thing).
# - Surveillance cameras in public places for spotting suspicious activities or crimes, and a computer system called 'Hawk-eye' for tracking the trajectory of the ball in various sports are typical examples of applying object tracking in a real life.
#
#
# **Goals**
#
#
# 1. We will use MOT17Det Dataset
# 2. First part: Object Detection with **Faster R-CNN**
# 3. Second part: Multiple Object(ID) Tracking with  **Simple Online and Realtime Tracking (SORT)** algorithm
#
#
#
# ---

# %% [markdown]
# **0. Preparation**
#
#
# *   For your convenience, it is recommended to mount your Google Drive first.
# *   Then create extra space for this tutorial in there.
#
#
# ---

# %%
from google.colab import drive
root = '/content/drive/'
drive.mount(root)
# Out:
# Mounted at /content/drive/

# %%
# Making Directory

import os 
from os.path import join

mot = "My Drive/Colab Notebooks/MOT/"   # a custom path. you can change if you want to
MOT_PATH = join(root,mot)
# !mkdir "{MOT_PATH}"

# %% [markdown]
# ---
#
#
# **1. Dataset**
#
#
# *   https://motchallenge.net/ : MOT17Det Dataset for Pedestrian Detection Challenge
# *   We will only use MOT17-09 dataset for our task.
#
#
# ---

# %%
# Download MOT17Det Dataset

# !wget -P "{MOT_PATH}" https://motchallenge.net/data/MOT17Det.zip
# !cd "{MOT_PATH}";unzip MOT17Det.zip
# Out:
#   inflating: test/MOT17-14/img1/000125.jpg
#   inflating: test/MOT17-14/img1/000126.jpg
#   inflating: test/MOT17-14/img1/000127.jpg
#   inflating: test/MOT17-14/img1/000128.jpg
#   inflating: test/MOT17-14/img1/000129.jpg
#   inflating: test/MOT17-14/img1/000130.jpg
#   inflating: test/MOT17-14/img1/000131.jpg
#   inflating: test/MOT17-14/img1/000132.jpg
#   inflating: test/MOT17-14/img1/000133.jpg
#   inflating: test/MOT17-14/img1/000134.jpg
#   inflating: test/MOT17-14/img1/000135.jpg
#   inflating: test/MOT17-14/img1/000136.jpg
#   inflating: test/MOT17-14/img1/000137.jpg
#   inflating: test/MOT17-14/img1/000138.jpg
#   inflating: test/MOT17-14/img1/000139.jpg
#   inflating: test/MOT17-14/img1/000140.jpg
#   inflating: test/MOT17-14/img1/000141.jpg
#   inflating: test/MOT17-14/img1/000142.jpg
#   inflating: test/MOT17-14/img1/000143.jpg
#   inflating: test/MOT17-14/img1/000144.jpg
#   inflating: test/MOT17-14/img1/000145.jpg
#   inflating: test/MOT17-14/img1/000146.jpg
#   inflating: test/MOT17-14/img1/000147.jpg
#   inflating: test/MOT17-14/img1/000148.jpg
#   inflating: test/MOT17-14/img1/000149.jpg
#   inflating: test/MOT17-14/img1/000150.jpg
#   inflating: test/MOT17-14/img1/000151.jpg
#   inflating: test/MOT17-14/img1/000152.jpg
#   inflating: test/MOT17-14/img1/000153.jpg
#   inflating: test/MOT17-14/img1/000154.jpg
#   inflating: test/MOT17-14/img1/000155.jpg
#   inflating: test/MOT17-14/img1/000156.jpg
#   inflating: test/MOT17-14/img1/000157.jpg
#   inflating: test/MOT17-14/img1/000158.jpg
#   inflating: test/MOT17-14/img1/000159.jpg
#   inflating: test/MOT17-14/img1/000160.jpg
#   inflating: test/MOT17-14/img1/000161.jpg
#   inflating: test/MOT17-14/img1/000162.jpg
#   inflating: test/MOT17-14/img1/000163.jpg
#   inflating: test/MOT17-14/img1/000164.jpg
#   inflating: test/MOT17-14/img1/000165.jpg
#   inflating: test/MOT17-14/img1/000166.jpg
#   inflating: test/MOT17-14/img1/000167.jpg
#   inflating: test/MOT17-14/img1/000168.jpg
#   inflating: test/MOT17-14/img1/000169.jpg
#   inflating: test/MOT17-14/img1/000170.jpg
#   inflating: test/MOT17-14/img1/000171.jpg
#   inflating: test/MOT17-14/img1/000172.jpg
#   inflating: test/MOT17-14/img1/000173.jpg
#   inflating: test/MOT17-14/img1/000174.jpg
#   inflating: test/MOT17-14/img1/000175.jpg
#   inflating: test/MOT17-14/img1/000176.jpg
#   inflating: test/MOT17-14/img1/000177.jpg
#   inflating: test/MOT17-14/img1/000178.jpg
#   inflating: test/MOT17-14/img1/000179.jpg
#   inflating: test/MOT17-14/img1/000180.jpg
#   inflating: test/MOT17-14/img1/000181.jpg
#   inflating: test/MOT17-14/img1/000182.jpg
#   inflating: test/MOT17-14/img1/000183.jpg
#   inflating: test/MOT17-14/img1/000184.jpg
#   inflating: test/MOT17-14/img1/000185.jpg
#   inflating: test/MOT17-14/img1/000186.jpg
#   inflating: test/MOT17-14/img1/000187.jpg
#   inflating: test/MOT17-14/img1/000188.jpg
#   inflating: test/MOT17-14/img1/000189.jpg
#   inflating: test/MOT17-14/img1/000190.jpg
#   inflating: test/MOT17-14/img1/000191.jpg
#   inflating: test/MOT17-14/img1/000192.jpg
#   inflating: test/MOT17-14/img1/000193.jpg
#   inflating: test/MOT17-14/img1/000194.jpg
#   inflating: test/MOT17-14/img1/000195.jpg
#   inflating: test/MOT17-14/img1/000196.jpg
#   inflating: test/MOT17-14/img1/000197.jpg
#   inflating: test/MOT17-14/img1/000198.jpg
#   inflating: test/MOT17-14/img1/000199.jpg
#   inflating: test/MOT17-14/img1/000200.jpg
#   inflating: test/MOT17-14/img1/000201.jpg
#   inflating: test/MOT17-14/img1/000202.jpg
#   inflating: test/MOT17-14/img1/000203.jpg
#   inflating: test/MOT17-14/img1/000204.jpg
#   inflating: test/MOT17-14/img1/000205.jpg
#   inflating: test/MOT17-14/img1/000206.jpg
#   inflating: test/MOT17-14/img1/000207.jpg
#   inflating: test/MOT17-14/img1/000208.jpg
#   inflating: test/MOT17-14/img1/000209.jpg
#   inflating: test/MOT17-14/img1/000210.jpg
#   inflating: test/MOT17-14/img1/000211.jpg
#   inflating: test/MOT17-14/img1/000212.jpg
#   inflating: test/MOT17-14/img1/000213.jpg
#   inflating: test/MOT17-14/img1/000214.jpg
#   inflating: test/MOT17-14/img1/000215.jpg
#   inflating: test/MOT17-14/img1/000216.jpg
#   inflating: test/MOT17-14/img1/000217.jpg
#   inflating: test/MOT17-14/img1/000218.jpg
#   inflating: test/MOT17-14/img1/000219.jpg
#   inflating: test/MOT17-14/img1/000220.jpg
#   inflating: test/MOT17-14/img1/000221.jpg
#   inflating: test/MOT17-14/img1/000222.jpg
#   inflating: test/MOT17-14/img1/000223.jpg
#   inflating: test/MOT17-14/img1/000224.jpg
#   inflating: test/MOT17-14/img1/000225.jpg
#   inflating: test/MOT17-14/img1/000226.jpg
#   inflating: test/MOT17-14/img1/000227.jpg
#   inflating: test/MOT17-14/img1/000228.jpg
#   inflating: test/MOT17-14/img1/000229.jpg
#   inflating: test/MOT17-14/img1/000230.jpg
#   inflating: test/MOT17-14/img1/000231.jpg
#   inflating: test/MOT17-14/img1/000232.jpg
#   inflating: test/MOT17-14/img1/000233.jpg
#   inflating: test/MOT17-14/img1/000234.jpg
#   inflating: test/MOT17-14/img1/000235.jpg
#   inflating: test/MOT17-14/img1/000236.jpg
#   inflating: test/MOT17-14/img1/000237.jpg
#   inflating: test/MOT17-14/img1/000238.jpg
#   inflating: test/MOT17-14/img1/000239.jpg
#   inflating: test/MOT17-14/img1/000240.jpg
#   inflating: test/MOT17-14/img1/000241.jpg
#   inflating: test/MOT17-14/img1/000242.jpg
#   inflating: test/MOT17-14/img1/000243.jpg
#   inflating: test/MOT17-14/img1/000244.jpg
#   inflating: test/MOT17-14/img1/000245.jpg
#   inflating: test/MOT17-14/img1/000246.jpg
#   inflating: test/MOT17-14/img1/000247.jpg
#   inflating: test/MOT17-14/img1/000248.jpg
#   inflating: test/MOT17-14/img1/000249.jpg
#   inflating: test/MOT17-14/img1/000250.jpg
#   inflating: test/MOT17-14/img1/000251.jpg
#   inflating: test/MOT17-14/img1/000252.jpg
#   inflating: test/MOT17-14/img1/000253.jpg
#   inflating: test/MOT17-14/img1/000254.jpg
#   inflating: test/MOT17-14/img1/000255.jpg
#   inflating: test/MOT17-14/img1/000256.jpg
#   inflating: test/MOT17-14/img1/000257.jpg
#   inflating: test/MOT17-14/img1/000258.jpg
#   inflating: test/MOT17-14/img1/000259.jpg
#   inflating: test/MOT17-14/img1/000260.jpg
#   inflating: test/MOT17-14/img1/000261.jpg
#   inflating: test/MOT17-14/img1/000262.jpg
#   inflating: test/MOT17-14/img1/000263.jpg
#   inflating: test/MOT17-14/img1/000264.jpg
#   inflating: test/MOT17-14/img1/000265.jpg
#   inflating: test/MOT17-14/img1/000266.jpg
#   inflating: test/MOT17-14/img1/000267.jpg
#   inflating: test/MOT17-14/img1/000268.jpg
#   inflating: test/MOT17-14/img1/000269.jpg
#   inflating: test/MOT17-14/img1/000270.jpg
#   inflating: test/MOT17-14/img1/000271.jpg
#   inflating: test/MOT17-14/img1/000272.jpg
#   inflating: test/MOT17-14/img1/000273.jpg
#   inflating: test/MOT17-14/img1/000274.jpg
#   inflating: test/MOT17-14/img1/000275.jpg
#   inflating: test/MOT17-14/img1/000276.jpg
#   inflating: test/MOT17-14/img1/000277.jpg
#   inflating: test/MOT17-14/img1/000278.jpg
#   inflating: test/MOT17-14/img1/000279.jpg
#   inflating: test/MOT17-14/img1/000280.jpg
#   inflating: test/MOT17-14/img1/000281.jpg
#   inflating: test/MOT17-14/img1/000282.jpg
#   inflating: test/MOT17-14/img1/000283.jpg
#   inflating: test/MOT17-14/img1/000284.jpg
#   inflating: test/MOT17-14/img1/000285.jpg
#   inflating: test/MOT17-14/img1/000286.jpg
#   inflating: test/MOT17-14/img1/000287.jpg
#   inflating: test/MOT17-14/img1/000288.jpg
#   inflating: test/MOT17-14/img1/000289.jpg
#   inflating: test/MOT17-14/img1/000290.jpg
#   inflating: test/MOT17-14/img1/000291.jpg
#   inflating: test/MOT17-14/img1/000292.jpg
#   inflating: test/MOT17-14/img1/000293.jpg
#   inflating: test/MOT17-14/img1/000294.jpg
#   inflating: test/MOT17-14/img1/000295.jpg
#   inflating: test/MOT17-14/img1/000296.jpg
#   inflating: test/MOT17-14/img1/000297.jpg
#   inflating: test/MOT17-14/img1/000298.jpg
#   inflating: test/MOT17-14/img1/000299.jpg
#   inflating: test/MOT17-14/img1/000300.jpg
#   inflating: test/MOT17-14/img1/000301.jpg
#   inflating: test/MOT17-14/img1/000302.jpg
#   inflating: test/MOT17-14/img1/000303.jpg
#   inflating: test/MOT17-14/img1/000304.jpg
#   inflating: test/MOT17-14/img1/000305.jpg
#   inflating: test/MOT17-14/img1/000306.jpg
#   inflating: test/MOT17-14/img1/000307.jpg
#   inflating: test/MOT17-14/img1/000308.jpg
#   inflating: test/MOT17-14/img1/000309.jpg
#   inflating: test/MOT17-14/img1/000310.jpg
#   inflating: test/MOT17-14/img1/000311.jpg
#   inflating: test/MOT17-14/img1/000312.jpg
#   inflating: test/MOT17-14/img1/000313.jpg
#   inflating: test/MOT17-14/img1/000314.jpg
#   inflating: test/MOT17-14/img1/000315.jpg
#   inflating: test/MOT17-14/img1/000316.jpg
#   inflating: test/MOT17-14/img1/000317.jpg
#   inflating: test/MOT17-14/img1/000318.jpg
#   inflating: test/MOT17-14/img1/000319.jpg
#   inflating: test/MOT17-14/img1/000320.jpg
#   inflating: test/MOT17-14/img1/000321.jpg
#   inflating: test/MOT17-14/img1/000322.jpg
#   inflating: test/MOT17-14/img1/000323.jpg
#   inflating: test/MOT17-14/img1/000324.jpg
#   inflating: test/MOT17-14/img1/000325.jpg
#   inflating: test/MOT17-14/img1/000326.jpg
#   inflating: test/MOT17-14/img1/000327.jpg
#   inflating: test/MOT17-14/img1/000328.jpg
#   inflating: test/MOT17-14/img1/000329.jpg
#   inflating: test/MOT17-14/img1/000330.jpg
#   inflating: test/MOT17-14/img1/000331.jpg
#   inflating: test/MOT17-14/img1/000332.jpg
#   inflating: test/MOT17-14/img1/000333.jpg
#   inflating: test/MOT17-14/img1/000334.jpg
#   inflating: test/MOT17-14/img1/000335.jpg
#   inflating: test/MOT17-14/img1/000336.jpg
#   inflating: test/MOT17-14/img1/000337.jpg
#   inflating: test/MOT17-14/img1/000338.jpg
#   inflating: test/MOT17-14/img1/000339.jpg
#   inflating: test/MOT17-14/img1/000340.jpg
#   inflating: test/MOT17-14/img1/000341.jpg
#   inflating: test/MOT17-14/img1/000342.jpg
#   inflating: test/MOT17-14/img1/000343.jpg
#   inflating: test/MOT17-14/img1/000344.jpg
#   inflating: test/MOT17-14/img1/000345.jpg
#   inflating: test/MOT17-14/img1/000346.jpg
#   inflating: test/MOT17-14/img1/000347.jpg
#   inflating: test/MOT17-14/img1/000348.jpg
#   inflating: test/MOT17-14/img1/000349.jpg
#   inflating: test/MOT17-14/img1/000350.jpg
#   inflating: test/MOT17-14/img1/000351.jpg
#   inflating: test/MOT17-14/img1/000352.jpg
#   inflating: test/MOT17-14/img1/000353.jpg
#   inflating: test/MOT17-14/img1/000354.jpg
#   inflating: test/MOT17-14/img1/000355.jpg
#   inflating: test/MOT17-14/img1/000356.jpg
#   inflating: test/MOT17-14/img1/000357.jpg
#   inflating: test/MOT17-14/img1/000358.jpg
#   inflating: test/MOT17-14/img1/000359.jpg
#   inflating: test/MOT17-14/img1/000360.jpg
#   inflating: test/MOT17-14/img1/000361.jpg
#   inflating: test/MOT17-14/img1/000362.jpg
#   inflating: test/MOT17-14/img1/000363.jpg
#   inflating: test/MOT17-14/img1/000364.jpg
#   inflating: test/MOT17-14/img1/000365.jpg
#   inflating: test/MOT17-14/img1/000366.jpg
#   inflating: test/MOT17-14/img1/000367.jpg
#   inflating: test/MOT17-14/img1/000368.jpg
#   inflating: test/MOT17-14/img1/000369.jpg
#   inflating: test/MOT17-14/img1/000370.jpg
#   inflating: test/MOT17-14/img1/000371.jpg
#   inflating: test/MOT17-14/img1/000372.jpg
#   inflating: test/MOT17-14/img1/000373.jpg
#   inflating: test/MOT17-14/img1/000374.jpg
#   inflating: test/MOT17-14/img1/000375.jpg
#   inflating: test/MOT17-14/img1/000376.jpg
#   inflating: test/MOT17-14/img1/000377.jpg
#   inflating: test/MOT17-14/img1/000378.jpg
#   inflating: test/MOT17-14/img1/000379.jpg
#   inflating: test/MOT17-14/img1/000380.jpg
#   inflating: test/MOT17-14/img1/000381.jpg
#   inflating: test/MOT17-14/img1/000382.jpg
#   inflating: test/MOT17-14/img1/000383.jpg
#   inflating: test/MOT17-14/img1/000384.jpg
#   inflating: test/MOT17-14/img1/000385.jpg
#   inflating: test/MOT17-14/img1/000386.jpg
#   inflating: test/MOT17-14/img1/000387.jpg
#   inflating: test/MOT17-14/img1/000388.jpg
#   inflating: test/MOT17-14/img1/000389.jpg
#   inflating: test/MOT17-14/img1/000390.jpg
#   inflating: test/MOT17-14/img1/000391.jpg
#   inflating: test/MOT17-14/img1/000392.jpg
#   inflating: test/MOT17-14/img1/000393.jpg
#   inflating: test/MOT17-14/img1/000394.jpg
#   inflating: test/MOT17-14/img1/000395.jpg
#   inflating: test/MOT17-14/img1/000396.jpg
#   inflating: test/MOT17-14/img1/000397.jpg
#   inflating: test/MOT17-14/img1/000398.jpg
#   inflating: test/MOT17-14/img1/000399.jpg
#   inflating: test/MOT17-14/img1/000400.jpg
#   inflating: test/MOT17-14/img1/000401.jpg
#   inflating: test/MOT17-14/img1/000402.jpg
#   inflating: test/MOT17-14/img1/000403.jpg
#   inflating: test/MOT17-14/img1/000404.jpg
#   inflating: test/MOT17-14/img1/000405.jpg
#   inflating: test/MOT17-14/img1/000406.jpg
#   inflating: test/MOT17-14/img1/000407.jpg
#   inflating: test/MOT17-14/img1/000408.jpg
#   inflating: test/MOT17-14/img1/000409.jpg
#   inflating: test/MOT17-14/img1/000410.jpg
#   inflating: test/MOT17-14/img1/000411.jpg
#   inflating: test/MOT17-14/img1/000412.jpg
#   inflating: test/MOT17-14/img1/000413.jpg
#   inflating: test/MOT17-14/img1/000414.jpg
#   inflating: test/MOT17-14/img1/000415.jpg
#   inflating: test/MOT17-14/img1/000416.jpg
#   inflating: test/MOT17-14/img1/000417.jpg
#   inflating: test/MOT17-14/img1/000418.jpg
#   inflating: test/MOT17-14/img1/000419.jpg
#   inflating: test/MOT17-14/img1/000420.jpg
#   inflating: test/MOT17-14/img1/000421.jpg
#   inflating: test/MOT17-14/img1/000422.jpg
#   inflating: test/MOT17-14/img1/000423.jpg
#   inflating: test/MOT17-14/img1/000424.jpg
#   inflating: test/MOT17-14/img1/000425.jpg
#   inflating: test/MOT17-14/img1/000426.jpg
#   inflating: test/MOT17-14/img1/000427.jpg
#   inflating: test/MOT17-14/img1/000428.jpg
#   inflating: test/MOT17-14/img1/000429.jpg
#   inflating: test/MOT17-14/img1/000430.jpg
#   inflating: test/MOT17-14/img1/000431.jpg
#   inflating: test/MOT17-14/img1/000432.jpg
#   inflating: test/MOT17-14/img1/000433.jpg
#   inflating: test/MOT17-14/img1/000434.jpg
#   inflating: test/MOT17-14/img1/000435.jpg
#   inflating: test/MOT17-14/img1/000436.jpg
#   inflating: test/MOT17-14/img1/000437.jpg
#   inflating: test/MOT17-14/img1/000438.jpg
#   inflating: test/MOT17-14/img1/000439.jpg
#   inflating: test/MOT17-14/img1/000440.jpg
#   inflating: test/MOT17-14/img1/000441.jpg
#   inflating: test/MOT17-14/img1/000442.jpg
#   inflating: test/MOT17-14/img1/000443.jpg
#   inflating: test/MOT17-14/img1/000444.jpg
#   inflating: test/MOT17-14/img1/000445.jpg
#   inflating: test/MOT17-14/img1/000446.jpg
#   inflating: test/MOT17-14/img1/000447.jpg
#   inflating: test/MOT17-14/img1/000448.jpg
#   inflating: test/MOT17-14/img1/000449.jpg
#   inflating: test/MOT17-14/img1/000450.jpg
#   inflating: test/MOT17-14/img1/000451.jpg
#   inflating: test/MOT17-14/img1/000452.jpg
#   inflating: test/MOT17-14/img1/000453.jpg
#   inflating: test/MOT17-14/img1/000454.jpg
#   inflating: test/MOT17-14/img1/000455.jpg
#   inflating: test/MOT17-14/img1/000456.jpg
#   inflating: test/MOT17-14/img1/000457.jpg
#   inflating: test/MOT17-14/img1/000458.jpg
#   inflating: test/MOT17-14/img1/000459.jpg
#   inflating: test/MOT17-14/img1/000460.jpg
#   inflating: test/MOT17-14/img1/000461.jpg
#   inflating: test/MOT17-14/img1/000462.jpg
#   inflating: test/MOT17-14/img1/000463.jpg
#   inflating: test/MOT17-14/img1/000464.jpg
#   inflating: test/MOT17-14/img1/000465.jpg
#   inflating: test/MOT17-14/img1/000466.jpg
#   inflating: test/MOT17-14/img1/000467.jpg
#   inflating: test/MOT17-14/img1/000468.jpg
#   inflating: test/MOT17-14/img1/000469.jpg
#   inflating: test/MOT17-14/img1/000470.jpg
#   inflating: test/MOT17-14/img1/000471.jpg
#   inflating: test/MOT17-14/img1/000472.jpg
#   inflating: test/MOT17-14/img1/000473.jpg
#   inflating: test/MOT17-14/img1/000474.jpg
#   inflating: test/MOT17-14/img1/000475.jpg
#   inflating: test/MOT17-14/img1/000476.jpg
#   inflating: test/MOT17-14/img1/000477.jpg
#   inflating: test/MOT17-14/img1/000478.jpg
#   inflating: test/MOT17-14/img1/000479.jpg
#   inflating: test/MOT17-14/img1/000480.jpg
#   inflating: test/MOT17-14/img1/000481.jpg
#   inflating: test/MOT17-14/img1/000482.jpg
#   inflating: test/MOT17-14/img1/000483.jpg
#   inflating: test/MOT17-14/img1/000484.jpg
#   inflating: test/MOT17-14/img1/000485.jpg
#   inflating: test/MOT17-14/img1/000486.jpg
#   inflating: test/MOT17-14/img1/000487.jpg
#   inflating: test/MOT17-14/img1/000488.jpg
#   inflating: test/MOT17-14/img1/000489.jpg
#   inflating: test/MOT17-14/img1/000490.jpg
#   inflating: test/MOT17-14/img1/000491.jpg
#   inflating: test/MOT17-14/img1/000492.jpg
#   inflating: test/MOT17-14/img1/000493.jpg
#   inflating: test/MOT17-14/img1/000494.jpg
#   inflating: test/MOT17-14/img1/000495.jpg
#   inflating: test/MOT17-14/img1/000496.jpg
#   inflating: test/MOT17-14/img1/000497.jpg
#   inflating: test/MOT17-14/img1/000498.jpg
#   inflating: test/MOT17-14/img1/000499.jpg
#   inflating: test/MOT17-14/img1/000500.jpg
#   inflating: test/MOT17-14/img1/000501.jpg
#   inflating: test/MOT17-14/img1/000502.jpg
#   inflating: test/MOT17-14/img1/000503.jpg
#   inflating: test/MOT17-14/img1/000504.jpg
#   inflating: test/MOT17-14/img1/000505.jpg
#   inflating: test/MOT17-14/img1/000506.jpg
#   inflating: test/MOT17-14/img1/000507.jpg
#   inflating: test/MOT17-14/img1/000508.jpg
#   inflating: test/MOT17-14/img1/000509.jpg
#   inflating: test/MOT17-14/img1/000510.jpg
#   inflating: test/MOT17-14/img1/000511.jpg
#   inflating: test/MOT17-14/img1/000512.jpg
#   inflating: test/MOT17-14/img1/000513.jpg
#   inflating: test/MOT17-14/img1/000514.jpg
#   inflating: test/MOT17-14/img1/000515.jpg
#   inflating: test/MOT17-14/img1/000516.jpg
#   inflating: test/MOT17-14/img1/000517.jpg
#   inflating: test/MOT17-14/img1/000518.jpg
#   inflating: test/MOT17-14/img1/000519.jpg
#   inflating: test/MOT17-14/img1/000520.jpg
#   inflating: test/MOT17-14/img1/000521.jpg
#   inflating: test/MOT17-14/img1/000522.jpg
#   inflating: test/MOT17-14/img1/000523.jpg
#   inflating: test/MOT17-14/img1/000524.jpg
#   inflating: test/MOT17-14/img1/000525.jpg
#   inflating: test/MOT17-14/img1/000526.jpg
#   inflating: test/MOT17-14/img1/000527.jpg
#   inflating: test/MOT17-14/img1/000528.jpg
#   inflating: test/MOT17-14/img1/000529.jpg
#   inflating: test/MOT17-14/img1/000530.jpg
#   inflating: test/MOT17-14/img1/000531.jpg
#   inflating: test/MOT17-14/img1/000532.jpg
#   inflating: test/MOT17-14/img1/000533.jpg
#   inflating: test/MOT17-14/img1/000534.jpg
#   inflating: test/MOT17-14/img1/000535.jpg
#   inflating: test/MOT17-14/img1/000536.jpg
#   inflating: test/MOT17-14/img1/000537.jpg
#   inflating: test/MOT17-14/img1/000538.jpg
#   inflating: test/MOT17-14/img1/000539.jpg
#   inflating: test/MOT17-14/img1/000540.jpg
#   inflating: test/MOT17-14/img1/000541.jpg
#   inflating: test/MOT17-14/img1/000542.jpg
#   inflating: test/MOT17-14/img1/000543.jpg
#   inflating: test/MOT17-14/img1/000544.jpg
#   inflating: test/MOT17-14/img1/000545.jpg
#   inflating: test/MOT17-14/img1/000546.jpg
#   inflating: test/MOT17-14/img1/000547.jpg
#   inflating: test/MOT17-14/img1/000548.jpg
#   inflating: test/MOT17-14/img1/000549.jpg
#   inflating: test/MOT17-14/img1/000550.jpg
#   inflating: test/MOT17-14/img1/000551.jpg
#   inflating: test/MOT17-14/img1/000552.jpg
#   inflating: test/MOT17-14/img1/000553.jpg
#   inflating: test/MOT17-14/img1/000554.jpg
#   inflating: test/MOT17-14/img1/000555.jpg
#   inflating: test/MOT17-14/img1/000556.jpg
#   inflating: test/MOT17-14/img1/000557.jpg
#   inflating: test/MOT17-14/img1/000558.jpg
#   inflating: test/MOT17-14/img1/000559.jpg
#   inflating: test/MOT17-14/img1/000560.jpg
#   inflating: test/MOT17-14/img1/000561.jpg
#   inflating: test/MOT17-14/img1/000562.jpg
#   inflating: test/MOT17-14/img1/000563.jpg
#   inflating: test/MOT17-14/img1/000564.jpg
#   inflating: test/MOT17-14/img1/000565.jpg
#   inflating: test/MOT17-14/img1/000566.jpg
#   inflating: test/MOT17-14/img1/000567.jpg
#   inflating: test/MOT17-14/img1/000568.jpg
#   inflating: test/MOT17-14/img1/000569.jpg
#   inflating: test/MOT17-14/img1/000570.jpg
#   inflating: test/MOT17-14/img1/000571.jpg
#   inflating: test/MOT17-14/img1/000572.jpg
#   inflating: test/MOT17-14/img1/000573.jpg
#   inflating: test/MOT17-14/img1/000574.jpg
#   inflating: test/MOT17-14/img1/000575.jpg
#   inflating: test/MOT17-14/img1/000576.jpg
#   inflating: test/MOT17-14/img1/000577.jpg
#   inflating: test/MOT17-14/img1/000578.jpg
#   inflating: test/MOT17-14/img1/000579.jpg
#   inflating: test/MOT17-14/img1/000580.jpg
#   inflating: test/MOT17-14/img1/000581.jpg
#   inflating: test/MOT17-14/img1/000582.jpg
#   inflating: test/MOT17-14/img1/000583.jpg
#   inflating: test/MOT17-14/img1/000584.jpg
#   inflating: test/MOT17-14/img1/000585.jpg
#   inflating: test/MOT17-14/img1/000586.jpg
#   inflating: test/MOT17-14/img1/000587.jpg
#   inflating: test/MOT17-14/img1/000588.jpg
#   inflating: test/MOT17-14/img1/000589.jpg
#   inflating: test/MOT17-14/img1/000590.jpg
#   inflating: test/MOT17-14/img1/000591.jpg
#   inflating: test/MOT17-14/img1/000592.jpg
#   inflating: test/MOT17-14/img1/000593.jpg
#   inflating: test/MOT17-14/img1/000594.jpg
#   inflating: test/MOT17-14/img1/000595.jpg
#   inflating: test/MOT17-14/img1/000596.jpg
#   inflating: test/MOT17-14/img1/000597.jpg
#   inflating: test/MOT17-14/img1/000598.jpg
#   inflating: test/MOT17-14/img1/000599.jpg
#   inflating: test/MOT17-14/img1/000600.jpg
#   inflating: test/MOT17-14/img1/000601.jpg
#   inflating: test/MOT17-14/img1/000602.jpg
#   inflating: test/MOT17-14/img1/000603.jpg
#   inflating: test/MOT17-14/img1/000604.jpg
#   inflating: test/MOT17-14/img1/000605.jpg
#   inflating: test/MOT17-14/img1/000606.jpg
#   inflating: test/MOT17-14/img1/000607.jpg
#   inflating: test/MOT17-14/img1/000608.jpg
#   inflating: test/MOT17-14/img1/000609.jpg
#   inflating: test/MOT17-14/img1/000610.jpg
#   inflating: test/MOT17-14/img1/000611.jpg
#   inflating: test/MOT17-14/img1/000612.jpg
#   inflating: test/MOT17-14/img1/000613.jpg
#   inflating: test/MOT17-14/img1/000614.jpg
#   inflating: test/MOT17-14/img1/000615.jpg
#   inflating: test/MOT17-14/img1/000616.jpg
#   inflating: test/MOT17-14/img1/000617.jpg
#   inflating: test/MOT17-14/img1/000618.jpg
#   inflating: test/MOT17-14/img1/000619.jpg
#   inflating: test/MOT17-14/img1/000620.jpg
#   inflating: test/MOT17-14/img1/000621.jpg
#   inflating: test/MOT17-14/img1/000622.jpg
#   inflating: test/MOT17-14/img1/000623.jpg
#   inflating: test/MOT17-14/img1/000624.jpg
#   inflating: test/MOT17-14/img1/000625.jpg
#   inflating: test/MOT17-14/img1/000626.jpg
#   inflating: test/MOT17-14/img1/000627.jpg
#   inflating: test/MOT17-14/img1/000628.jpg

# %%
# Remove unwanted data for drive volume issue (optional)

# !cd "{MOT_PATH}";rm -rf test
# !cd "{MOT_PATH}";rm -rf train/MOT17-02;rm -rf train/MOT17-04;rm -rf train/MOT17-05
# !cd "{MOT_PATH}";rm -rf train/MOT17-10;rm -rf train/MOT17-11;rm -rf train/MOT17-13
# Out:
# ^C

# %%
import sys

motdata = join(MOT_PATH,'train/MOT17-09/img1/')
sys.path.append(motdata)

# %%
# Example: Original picture before detection

import matplotlib.pylab as plt
import cv2

list_motdata = os.listdir(motdata)  
list_motdata.sort()

img_ex_path = motdata + list_motdata[0]
img_ex_origin = cv2.imread(img_ex_path)
img_ex = cv2.cvtColor(img_ex_origin, cv2.COLOR_BGR2RGB)

plt.imshow(img_ex)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-af12ab2489e2> in <module>()
#       7 list_motdata.sort()
#       8
# ----> 9 img_ex_path = motdata + list_motdata[0]
#      10 img_ex_origin = cv2.imread(img_ex_path)
#      11 img_ex = cv2.cvtColor(img_ex_origin, cv2.COLOR_BGR2RGB)
#
# IndexError: list index out of range

# %% [markdown]
# ---
#
#
# **2. Object Detection with Faster R-CNN**
#
# *  We will use a pretrained Faster R-CNN model using ResNet50 as a backbone with FPN.
#
#
#
#
#
# ---

# %%
# Import required packages/modules first

from PIL import Image
import numpy as np
import torch
import torchvision
from torchvision import transforms as T

# %%
# Download the pretrained Faster R-CNN model from torchvision

model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
model.eval()

# %%
# Define the class names given by PyTorch's official Docs

COCO_INSTANCE_CATEGORY_NAMES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# %%
# Defining a function for get a prediction result from the model

def get_prediction(img_path, threshold):
  img = Image.open(img_path) # Load the image
  transform = T.Compose([T.ToTensor()]) # Defing PyTorch Transform
  img = transform(img) # Apply the transform to the image
  pred = model([img]) # Pass the image to the model
  pred_class = [COCO_INSTANCE_CATEGORY_NAMES[i] for i in list(pred[0]['labels'].numpy())] # Get the Prediction Score
  pred_boxes = [[(i[0], i[1]), (i[2], i[3])] for i in list(pred[0]['boxes'].detach().numpy())] # Bounding boxes
  pred_score = list(pred[0]['scores'].detach().numpy())
  pred_t = [pred_score.index(x) for x in pred_score if x > threshold][-1] # Get list of index with score greater than threshold.
  pred_boxes = pred_boxes[:pred_t+1]
  pred_class = pred_class[:pred_t+1]
  return pred_boxes, pred_class

# %%
# Defining a api function for object detection

def object_detection_api(img_path, threshold=0.5, rect_th=3, text_size=1.5, text_th=3):
 
  boxes, pred_cls = get_prediction(img_path, threshold) # Get predictions
  img = cv2.imread(img_path) # Read image with cv2
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Convert to RGB
  for i in range(len(boxes)):
    cv2.rectangle(img, boxes[i][0], boxes[i][1],color=(0, 255, 0), thickness=rect_th) # Draw Rectangle with the coordinates
    cv2.putText(img,pred_cls[i], boxes[i][0],  cv2.FONT_HERSHEY_SIMPLEX, text_size, (0,255,0),thickness=text_th) # Write the prediction class
  plt.figure(figsize=(15,20)) # display the output image
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])
  plt.show()

# %%
# Example: After detection
object_detection_api(img_ex_path,threshold=0.8)

# %% [markdown]
# *   The picture above is an example of applying Detection Network (in our case, Faster R-CNN).
# *   Since the purpose of dataset we are using is 'tracking', you can see that most of the detected classes are 'person'.
# *   We need a prediction result (bbs offset, class label, pred scores) for all the images.

# %% [markdown]
# ---
#
#
# **3. Object ID Tracking with SORT**
#
#
# *   Simple Online and Realtime Tracking (SORT) algorithm for object ID tracking
#
# ---

# %%
# Git clone: SORT Algorithm

# !cd "{MOT_PATH}";git clone https://github.com/abewley/sort.git
  
sort = join(MOT_PATH,'sort/')
sys.path.append(sort)

# %%
# requirement for sort
# !cd "{sort}";pip install -r requirements.txt

# %%
# Optional: if error occurs, you might need to re-install scikit-image and imgaug

# !pip uninstall scikit-image
# !pip uninstall imgaug
# !pip install imgaug
# !pip install -U scikit-image

import skimage
print(skimage.__version__)

# %%
# Detection information on all the images is well-refined as a json file, which is available at our course git repo

# !cd "{MOT_PATH}";git clone https://github.com/mlvlab/COSE474.git

# %%
import json
import collections
from pprint import pprint
from sort import *

jsonpath = join(MOT_PATH,'COSE474/3_MOT_detinfo.json')

with open(jsonpath) as data_file:    
   data = json.load(data_file)
odata = collections.OrderedDict(sorted(data.items()))

# %%
# Let's check out downloaded json file

pprint(odata)

# %% [markdown]
# ---
#
#
#
# *   For each image, bbs offset, class label, pred scores are all annotated.
# *   Labels are annotated as a number - not a word, and for further information, go to the website below.
# * https://tech.amikelive.com/node-718/what-object-categories-labels-are-in-coco-dataset/
#
#
#
# ---

# %%
img_path = motdata    # img root path

# Making new directory for saving results
save_path = join(MOT_PATH,'save/')
# !mkdir "{save_path}"

# %%
mot_tracker = Sort()      # Tracker using SORT Algorithm

# %%
for key in odata.keys():   
    arrlist = []
    det_img = cv2.imread(os.path.join(img_path, key))
    overlay = det_img.copy()
    det_result = data[key] 
    
    for info in det_result:
        bbox = info['bbox']
        labels = info['labels']
        scores = info['scores']
        templist = bbox+[scores]
        
        if labels == 1: # label 1 is a person in MS COCO Dataset
            arrlist.append(templist)
            
    track_bbs_ids = mot_tracker.update(np.array(arrlist))
    
    mot_imgid = key.replace('.jpg','')
    newname = save_path + mot_imgid + '_mot.jpg'
    print(mot_imgid)
    
    for j in range(track_bbs_ids.shape[0]):  
        ele = track_bbs_ids[j, :]
        x = int(ele[0])
        y = int(ele[1])
        x2 = int(ele[2])
        y2 = int(ele[3])
        track_label = str(int(ele[4])) 
        cv2.rectangle(det_img, (x, y), (x2, y2), (0, 255, 255), 4)
        cv2.putText(det_img, '#'+track_label, (x+5, y-10), 0,0.6,(0,255,255),thickness=2)
        
    cv2.imwrite(newname,det_img)

# %% [markdown]
# ---
# It's all done!
#
#
# *   Finally, you can get a sequence of image with each Tracking ID for every detected person.
# *   Check '3_MOT_result.gif' for whole demo experience.
#
#
#
# ---
